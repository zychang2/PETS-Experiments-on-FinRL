# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# %cd /content/gdrive/My Drive/FinRL-test
# Out:
# Mounted at /content/gdrive/
# /content/gdrive/My Drive/FinRL-test

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# !pip install wrds
# !pip install swig
# !pip install gymnasium
# !pip install stable-baselines3
# !pip install stockstats
# !pip install alpaca-trade-api
# !pip install exchange-calendars
# !pip install pyfolio
# Out:
# Collecting wrds
#   Downloading wrds-3.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy<1.27,>=1.26 in /usr/local/lib/python3.10/dist-packages (from wrds) (1.26.4)
# Collecting packaging<23.3 (from wrds)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pandas<2.3,>=2.2 in /usr/local/lib/python3.10/dist-packages (from wrds) (2.2.2)
# Collecting psycopg2-binary<2.10,>=2.9 (from wrds)
#   Downloading psycopg2_binary-2.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting scipy<1.13,>=1.12 (from wrds)
#   Downloading scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: sqlalchemy<2.1,>=2 in /usr/local/lib/python3.10/dist-packages (from wrds) (2.0.36)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<2.3,>=2.2->wrds) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.3,>=2.2->wrds) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<2.3,>=2.2->wrds) (2024.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy<2.1,>=2->wrds) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy<2.1,>=2->wrds) (3.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<2.3,>=2.2->wrds) (1.16.0)
# Downloading wrds-3.2.0-py3-none-any.whl (13 kB)
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.9 MB/s eta 0:00:00
# Downloading psycopg2_binary-2.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 57.5 MB/s eta 0:00:00
# Downloading scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.4/38.4 MB 30.0 MB/s eta 0:00:00
# Installing collected packages: scipy, psycopg2-binary, packaging, wrds
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
# Successfully installed packaging-23.2 psycopg2-binary-2.9.10 scipy-1.12.0 wrds-3.2.0
# Collecting swig
#   Downloading swig-4.3.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (3.5 kB)
# Downloading swig-4.3.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 27.7 MB/s eta 0:00:00
# Installing collected packages: swig
# Successfully installed swig-4.3.0
# Collecting gymnasium
#   Downloading gymnasium-1.0.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Downloading gymnasium-1.0.0-py3-none-any.whl (958 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 18.4 MB/s eta 0:00:00
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium
# Successfully installed farama-notifications-0.0.4 gymnasium-1.0.0
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.4.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (1.0.0)
# Requirement already satisfied: numpy<2.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.5.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (3.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (3.8.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.13->stable-baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable-baselines3) (3.0.2)
# Downloading stable_baselines3-2.4.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: stable-baselines3
# Successfully installed stable-baselines3-2.4.0
# Collecting stockstats
#   Downloading stockstats-0.6.2-py2.py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.10/dist-packages (from stockstats) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from stockstats) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->stockstats) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->stockstats) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->stockstats) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.24.2->stockstats) (1.16.0)
# Downloading stockstats-0.6.2-py2.py3-none-any.whl (30 kB)
# Installing collected packages: stockstats
# Successfully installed stockstats-0.6.2
# Collecting alpaca-trade-api
#   Downloading alpaca_trade_api-3.2.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: pandas>=0.18.1 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api) (2.2.2)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api) (1.26.4)
# Requirement already satisfied: requests<3,>2 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api) (2.32.3)
# Collecting urllib3<2,>1.24 (from alpaca-trade-api)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api) (1.8.0)
# Collecting websockets<11,>=9.0 (from alpaca-trade-api)
#   Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Collecting msgpack==1.0.3 (from alpaca-trade-api)
#   Downloading msgpack-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: aiohttp<4,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api) (3.11.2)
# Collecting PyYAML==6.0.1 (from alpaca-trade-api)
#   Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting deprecation==2.1.0 (from alpaca-trade-api)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from deprecation==2.1.0->alpaca-trade-api) (23.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (4.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18.1->alpaca-trade-api) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18.1->alpaca-trade-api) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18.1->alpaca-trade-api) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>2->alpaca-trade-api) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>2->alpaca-trade-api) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>2->alpaca-trade-api) (2024.8.30)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from multidict<7.0,>=4.5->aiohttp<4,>=3.8.3->alpaca-trade-api) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.18.1->alpaca-trade-api) (1.16.0)
# Downloading alpaca_trade_api-3.2.0-py3-none-any.whl (34 kB)
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading msgpack-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.7/323.7 kB 14.0 MB/s eta 0:00:00
# Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.5/705.5 kB 32.7 MB/s eta 0:00:00
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 12.8 MB/s eta 0:00:00
# Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 9.4 MB/s eta 0:00:00
# Installing collected packages: msgpack, websockets, urllib3, PyYAML, deprecation, alpaca-trade-api
#   Attempting uninstall: msgpack
#     Found existing installation: msgpack 1.1.0
#     Uninstalling msgpack-1.1.0:
#       Successfully uninstalled msgpack-1.1.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.3
#     Uninstalling urllib3-2.2.3:
#       Successfully uninstalled urllib3-2.2.3
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.2
#     Uninstalling PyYAML-6.0.2:
#       Successfully uninstalled PyYAML-6.0.2
# Successfully installed PyYAML-6.0.1 alpaca-trade-api-3.2.0 deprecation-2.1.0 msgpack-1.0.3 urllib3-1.26.20 websockets-10.4
# Collecting exchange-calendars
#   Downloading exchange_calendars-4.6-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from exchange-calendars) (1.26.4)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.10/dist-packages (from exchange-calendars) (2.2.2)
# Collecting pyluach (from exchange-calendars)
#   Downloading pyluach-2.2.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from exchange-calendars) (0.12.1)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.10/dist-packages (from exchange-calendars) (2024.2)
# Collecting korean_lunar_calendar (from exchange-calendars)
#   Downloading korean_lunar_calendar-0.3.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5->exchange-calendars) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5->exchange-calendars) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5->exchange-calendars) (1.16.0)
# Downloading exchange_calendars-4.6-py3-none-any.whl (196 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.8/196.8 kB 8.2 MB/s eta 0:00:00
# Downloading korean_lunar_calendar-0.3.1-py3-none-any.whl (9.0 kB)
# Downloading pyluach-2.2.0-py3-none-any.whl (25 kB)
# Installing collected packages: korean_lunar_calendar, pyluach, exchange-calendars
# Successfully installed exchange-calendars-4.6 korean_lunar_calendar-0.3.1 pyluach-2.2.0
# Collecting pyfolio
#   Downloading pyfolio-0.9.2.tar.gz (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ipython>=3.2.3 in /usr/local/lib/python3.10/dist-packages (from pyfolio) (7.34.0)
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from pyfolio) (3.8.0)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from pyfolio) (1.26.4)
# Requirement already satisfied: pandas>=0.18.1 in /usr/local/lib/python3.10/dist-packages (from pyfolio) (2.2.2)
# Requirement already satisfied: pytz>=2014.10 in /usr/local/lib/python3.10/dist-packages (from pyfolio) (2024.2)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from pyfolio) (1.12.0)
# Requirement already satisfied: scikit-learn>=0.16.1 in /usr/local/lib/python3.10/dist-packages (from pyfolio) (1.5.2)
# Requirement already satisfied: seaborn>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from pyfolio) (0.13.2)
# Collecting empyrical>=0.5.0 (from pyfolio)
#   Downloading empyrical-0.5.5.tar.gz (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas-datareader>=0.2 in /usr/local/lib/python3.10/dist-packages (from empyrical>=0.5.0->pyfolio) (0.10.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio) (75.1.0)
# Collecting jedi>=0.16 (from ipython>=3.2.3->pyfolio)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18.1->pyfolio) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.16.1->pyfolio) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.16.1->pyfolio) (3.5.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio) (0.8.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from pandas-datareader>=0.2->empyrical>=0.5.0->pyfolio) (5.3.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pandas-datareader>=0.2->empyrical>=0.5.0->pyfolio) (2.32.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=3.2.3->pyfolio) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->pyfolio) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas-datareader>=0.2->empyrical>=0.5.0->pyfolio) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas-datareader>=0.2->empyrical>=0.5.0->pyfolio) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas-datareader>=0.2->empyrical>=0.5.0->pyfolio) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas-datareader>=0.2->empyrical>=0.5.0->pyfolio) (2024.8.30)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 41.3 MB/s eta 0:00:00
# Building wheels for collected packages: pyfolio, empyrical
#   Building wheel for pyfolio (setup.py) ... done
#   Created wheel for pyfolio: filename=pyfolio-0.9.2-py3-none-any.whl size=88656 sha256=d6975267804136ae1188ccfaf90cdee82c684ef680a4a06feb17bc821a20b4f7
#   Stored in directory: /root/.cache/pip/wheels/71/38/bc/e53700cfd8b0ad6b539d2fbaaf060ed8a299e7622a5b86ef42
#   Building wheel for empyrical (setup.py) ... done
#   Created wheel for empyrical: filename=empyrical-0.5.5-py3-none-any.whl size=39753 sha256=75630a325186ae94ef0cdbbacaf46b09e461c56758ec7e999187094d07bfda6e
#   Stored in directory: /root/.cache/pip/wheels/0e/2e/f2/d6d2d9a1eb8fbbd9949bb5d4c00f753e3b74e5bd7ed10b1d36
# Successfully built pyfolio empyrical
# Installing collected packages: jedi, empyrical, pyfolio
# Successfully installed empyrical-0.5.5 jedi-0.19.2 pyfolio-0.9.2

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/FinRL-test

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime
import importlib

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor import fixed_yahoodownloader # comment this if you chose other path above
importlib.reload(fixed_yahoodownloader) # comment this if you chose other path above
from finrl.meta.preprocessor.fixed_yahoodownloader import YahooDownloader #comment this if you chose the other path above

from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLEnsembleAgent
from finrl.agents.stablebaselines3.single_models import DRLSingleAgent
from finrl.agents.stablebaselines3.pets_model import PETSAgent
from finrl.agents.stablebaselines3.mbrl_model import MBRLAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas_datareader/compat/__init__.py:11: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   PANDAS_VERSION = LooseVersion(pd.__version__)

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
print(DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
TRAIN_START_DATE = '2010-01-01'
TRAIN_END_DATE = '2021-10-01'
TEST_START_DATE = '2021-10-01'
TEST_END_DATE = '2024-03-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (104573, 8)
# Display DataFrame:           date      close       high        low       open    volume  tic  day
# 0  2010-01-04  32.906185  41.099998  40.389999  40.810001   6894300  AXP    0
# 1  2010-01-05  32.833813  41.230000  40.369999  40.830002  10641200  AXP    1
# 2  2010-01-06  33.364567  41.669998  41.169998  41.230000   8399400  AXP    2
# 3  2010-01-07  33.905693  42.240002  41.110001  41.259998   8981700  AXP    3
# 4  2010-01-08  33.881454  42.480000  41.400002  41.759998   7907700  AXP    4

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
INDICATORS = ['macd',
            'rsi_30',
            'cci_30',
            'dx_30']
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 175
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "buy_cost_pct": 0.001,
    "sell_cost_pct": 0.001,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4,
    "print_verbosity":5

}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
#
# * The paper trains and validates 3 model-free agents (A2C, PPO, DDPG) using Rolling-Window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))
#
# * We train and validate 2 model-based agents (Random Shooting and PETS) using the sam Rolling-Window method without Ensembling.

# %% [markdown]
# ##Part 6.1 Ensemble Method

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window,
                 validation_window=validation_window,
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

SAC_model_kwargs = {
    "batch_size": 64,
    "buffer_size": 100000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

TD3_model_kwargs = {"batch_size": 100, "buffer_size": 1000000, "learning_rate": 0.0001}

timesteps_dict = {'a2c' : 10_000,
                 'ppo' : 10_000,
                 'ddpg' : 10_000,
                 'sac' : 10_000,
                 'td3' : 10_000
                 }

# %%
ensemble_df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 SAC_model_kwargs,
                                                 TD3_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2021-10-04
# ======a2c Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_126_2
# --------------------------------------
# | time/                 |            |
# |    fps                | 75         |
# |    iterations         | 100        |
# |    time_elapsed       | 6          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | -68.7      |
# |    reward             | -0.4306618 |
# |    std                | 1          |
# |    value_loss         | 4.96       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 82         |
# |    iterations         | 200        |
# |    time_elapsed       | 12         |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | -70.6      |
# |    reward             | -0.3066762 |
# |    std                | 1          |
# |    value_loss         | 5.69       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 81         |
# |    iterations         | 300        |
# |    time_elapsed       | 18         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | 37.5       |
# |    reward             | -3.9699404 |
# |    std                | 1.01       |
# |    value_loss         | 3          |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 85         |
# |    iterations         | 400        |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0.0198     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | 60.5       |
# |    reward             | 0.35365626 |
# |    std                | 1.01       |
# |    value_loss         | 7.11       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 84         |
# |    iterations         | 500        |
# |    time_elapsed       | 29         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0.0202     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -152       |
# |    reward             | -1.6481194 |
# |    std                | 1          |
# |    value_loss         | 17.2       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 86       |
# |    iterations         | 600      |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -41.3    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -1.18    |
# |    reward             | 0.659365 |
# |    std                | 1        |
# |    value_loss         | 0.0221   |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 700        |
# |    time_elapsed       | 39         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.000433  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | 53.1       |
# |    reward             | 0.60909766 |
# |    std                | 1          |
# |    value_loss         | 2.62       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 86        |
# |    iterations         | 800       |
# |    time_elapsed       | 46        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | 91.1      |
# |    reward             | -1.128412 |
# |    std                | 1         |
# |    value_loss         | 6.01      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 900        |
# |    time_elapsed       | 50         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | -141       |
# |    reward             | -0.2739956 |
# |    std                | 1          |
# |    value_loss         | 23.7       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 1000      |
# |    time_elapsed       | 57        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0.00885   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -228      |
# |    reward             | 1.4520949 |
# |    std                | 1.01      |
# |    value_loss         | 78.5      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 1100      |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | 24.5      |
# |    reward             | 2.4394681 |
# |    std                | 1.01      |
# |    value_loss         | 4.27      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 88        |
# |    iterations         | 1200      |
# |    time_elapsed       | 67        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | -0.299    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -17.7     |
# |    reward             | -0.662508 |
# |    std                | 1.01      |
# |    value_loss         | 0.847     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 1300       |
# |    time_elapsed       | 74         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -0.0204    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | 28.9       |
# |    reward             | 0.14507124 |
# |    std                | 1.01       |
# |    value_loss         | 1.65       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 1400       |
# |    time_elapsed       | 79         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0.357      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | 81.1       |
# |    reward             | -1.2555964 |
# |    std                | 1.01       |
# |    value_loss         | 4.58       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 1500       |
# |    time_elapsed       | 85         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | -0.181     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | 199        |
# |    reward             | -0.0518587 |
# |    std                | 1.01       |
# |    value_loss         | 22.4       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 1600      |
# |    time_elapsed       | 90        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -0.112    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -51.4     |
# |    reward             | 1.1227764 |
# |    std                | 1.01      |
# |    value_loss         | 12.9      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 88        |
# |    iterations         | 1700      |
# |    time_elapsed       | 95        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -328      |
# |    reward             | 7.4305606 |
# |    std                | 1.01      |
# |    value_loss         | 135       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 1800       |
# |    time_elapsed       | 102        |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | -0.169     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | -70.4      |
# |    reward             | 0.47400376 |
# |    std                | 1.01       |
# |    value_loss         | 4.82       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 88        |
# |    iterations         | 1900      |
# |    time_elapsed       | 107       |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | -0.146    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | 49.4      |
# |    reward             | 1.1219404 |
# |    std                | 1.01      |
# |    value_loss         | 2.15      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 2000       |
# |    time_elapsed       | 113        |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0.044      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | -4.39      |
# |    reward             | -1.0185566 |
# |    std                | 1.01       |
# |    value_loss         | 1.45       |
# --------------------------------------
# ======a2c Validation from:  2021-10-04 to  2022-01-03
# a2c Sharpe Ratio:  0.028149752316409433
# ======ddpg Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cuda device
# Logging to tensorboard_log/ddpg/ddpg_126_2
# day: 2957, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 5195332.32
# total_reward: 4195332.32
# total_cost: 5892.65
# total_trades: 45639
# Sharpe: 0.868
# =================================
# ======ddpg Validation from:  2021-10-04 to  2022-01-03
# ddpg Sharpe Ratio:  0.12231880879393169
# ======td3 Training========
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.0001}
# Using cuda device
# Logging to tensorboard_log/td3/td3_126_2
# day: 2957, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 4190018.41
# total_reward: 3190018.41
# total_cost: 1295.77
# total_trades: 53098
# Sharpe: 0.762
# =================================
# ======td3 Validation from:  2021-10-04 to  2022-01-03
# td3 Sharpe Ratio:  0.18866680198054253
# ======sac Training========
# {'batch_size': 64, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cuda device
# Logging to tensorboard_log/sac/sac_126_2
# day: 2957, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 5052430.59
# total_reward: 4052430.59
# total_cost: 177400.07
# total_trades: 57384
# Sharpe: 0.893
# =================================
# ======sac Validation from:  2021-10-04 to  2022-01-03
# sac Sharpe Ratio:  0.07439999610051388
# ======ppo Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/ppo/ppo_126_2
# -----------------------------------
# | time/              |            |
# |    fps             | 101        |
# |    iterations      | 1          |
# |    time_elapsed    | 20         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.48583663 |
# -----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 2           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016338008 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.0104     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.62        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0301     |
# |    reward               | 0.7099871   |
# |    std                  | 1           |
# |    value_loss           | 10          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 3           |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014347527 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.00559     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 29.3        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0202     |
# |    reward               | 0.18510403  |
# |    std                  | 1           |
# |    value_loss           | 36.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 4           |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012941437 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0131     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 35          |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0177     |
# |    reward               | 3.5904796   |
# |    std                  | 1.01        |
# |    value_loss           | 54.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 5           |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.014780387 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | 0.000714    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.04        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0195     |
# |    reward               | -0.15405777 |
# |    std                  | 1.01        |
# |    value_loss           | 16.8        |
# -----------------------------------------
# ======ppo Validation from:  2021-10-04 to  2022-01-03
# ppo Sharpe Ratio:  0.10050428751191605
# ======Best Model Retraining from:  2010-01-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2022-01-03
# ======a2c Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_189_2
# ----------------------------------------
# | time/                 |              |
# |    fps                | 98           |
# |    iterations         | 100          |
# |    time_elapsed       | 5            |
# |    total_timesteps    | 500          |
# | train/                |              |
# |    entropy_loss       | -41.3        |
# |    explained_variance | -0.254       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 99           |
# |    policy_loss        | -12.5        |
# |    reward             | -0.046822082 |
# |    std                | 1            |
# |    value_loss         | 0.434        |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 86        |
# |    iterations         | 200       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | 4.49      |
# |    reward             | 1.2657454 |
# |    std                | 1         |
# |    value_loss         | 0.752     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 90         |
# |    iterations         | 300        |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -62.6      |
# |    reward             | -4.5968924 |
# |    std                | 1          |
# |    value_loss         | 9.14       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 92        |
# |    iterations         | 400       |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -91.6     |
# |    reward             | 1.2911259 |
# |    std                | 1         |
# |    value_loss         | 16.3      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 88          |
# |    iterations         | 500         |
# |    time_elapsed       | 28          |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | -132        |
# |    reward             | 0.018128097 |
# |    std                | 1           |
# |    value_loss         | 17.3        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 90        |
# |    iterations         | 600       |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 415       |
# |    reward             | 20.049788 |
# |    std                | 1         |
# |    value_loss         | 139       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 700        |
# |    time_elapsed       | 39         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -216       |
# |    reward             | -1.2914696 |
# |    std                | 1          |
# |    value_loss         | 27         |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 89        |
# |    iterations         | 800       |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | 21.3      |
# |    reward             | 2.4753063 |
# |    std                | 1         |
# |    value_loss         | 0.894     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 90          |
# |    iterations         | 900         |
# |    time_elapsed       | 49          |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 899         |
# |    policy_loss        | -97.4       |
# |    reward             | -0.79351795 |
# |    std                | 1           |
# |    value_loss         | 12.2        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 88          |
# |    iterations         | 1000        |
# |    time_elapsed       | 56          |
# |    total_timesteps    | 5000        |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 999         |
# |    policy_loss        | 78.7        |
# |    reward             | -0.46391886 |
# |    std                | 0.998       |
# |    value_loss         | 6.69        |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 89       |
# |    iterations         | 1100     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -41      |
# |    explained_variance | -0.0391  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -10.8    |
# |    reward             | 4.42442  |
# |    std                | 0.996    |
# |    value_loss         | 6.11     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 89        |
# |    iterations         | 1200      |
# |    time_elapsed       | 67        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | -7.63e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -60.2     |
# |    reward             | -2.268613 |
# |    std                | 0.996     |
# |    value_loss         | 5.58      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 89        |
# |    iterations         | 1300      |
# |    time_elapsed       | 72        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0.0521    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 54.1      |
# |    reward             | 1.7903163 |
# |    std                | 0.998     |
# |    value_loss         | 4.06      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 90         |
# |    iterations         | 1400       |
# |    time_elapsed       | 77         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | 138        |
# |    reward             | -0.5700582 |
# |    std                | 0.999      |
# |    value_loss         | 16.5       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 89        |
# |    iterations         | 1500      |
# |    time_elapsed       | 84        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 160       |
# |    reward             | 3.0299017 |
# |    std                | 0.999     |
# |    value_loss         | 19.2      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 89         |
# |    iterations         | 1600       |
# |    time_elapsed       | 88         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | 157        |
# |    reward             | -1.2734097 |
# |    std                | 1          |
# |    value_loss         | 15.5       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 89       |
# |    iterations         | 1700     |
# |    time_elapsed       | 95       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -41.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -493     |
# |    reward             | 8.044576 |
# |    std                | 1        |
# |    value_loss         | 167      |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 89         |
# |    iterations         | 1800       |
# |    time_elapsed       | 100        |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | 368        |
# |    reward             | -26.346855 |
# |    std                | 1          |
# |    value_loss         | 367        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 90         |
# |    iterations         | 1900       |
# |    time_elapsed       | 105        |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -0.0232    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1899       |
# |    policy_loss        | 115        |
# |    reward             | 0.33071846 |
# |    std                | 1.01       |
# |    value_loss         | 12.1       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 89         |
# |    iterations         | 2000       |
# |    time_elapsed       | 111        |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | 36.9       |
# |    reward             | -0.8954335 |
# |    std                | 1.01       |
# |    value_loss         | 1.03       |
# --------------------------------------
# ======a2c Validation from:  2022-01-03 to  2022-04-04
# a2c Sharpe Ratio:  -0.10308917168139635
# ======ddpg Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cuda device
# Logging to tensorboard_log/ddpg/ddpg_189_2
# day: 3020, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 5799664.18
# total_reward: 4799664.18
# total_cost: 5927.62
# total_trades: 46534
# Sharpe: 0.954
# =================================
# ======ddpg Validation from:  2022-01-03 to  2022-04-04
# ddpg Sharpe Ratio:  -0.25121844197411086
# ======td3 Training========
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.0001}
# Using cuda device
# Logging to tensorboard_log/td3/td3_189_2
# day: 3020, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 4480025.86
# total_reward: 3480025.86
# total_cost: 1359.46
# total_trades: 42371
# Sharpe: 0.787
# =================================
# ======td3 Validation from:  2022-01-03 to  2022-04-04
# td3 Sharpe Ratio:  -0.15239505551857996
# ======sac Training========
# {'batch_size': 64, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cuda device
# Logging to tensorboard_log/sac/sac_189_2
# day: 3020, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 5034223.14
# total_reward: 4034223.14
# total_cost: 240661.84
# total_trades: 65587
# Sharpe: 0.824
# =================================
# ======sac Validation from:  2022-01-03 to  2022-04-04
# sac Sharpe Ratio:  -0.16381529262906955
# ======ppo Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/ppo/ppo_189_2
# ----------------------------------
# | time/              |           |
# |    fps             | 100       |
# |    iterations      | 1         |
# |    time_elapsed    | 20        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 1.1874099 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 2           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016152123 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.000701   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.87        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0206     |
# |    reward               | -1.4422628  |
# |    std                  | 1           |
# |    value_loss           | 15.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 3           |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.017895568 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | 0.00994     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 47.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0172     |
# |    reward               | -0.6123394  |
# |    std                  | 1           |
# |    value_loss           | 64          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 4           |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.016197365 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0536     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 25.4        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0179     |
# |    reward               | -1.2206893  |
# |    std                  | 1.01        |
# |    value_loss           | 62.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 5           |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.019468483 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | -0.084      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.94        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0241     |
# |    reward               | -0.1938938  |
# |    std                  | 1.01        |
# |    value_loss           | 9.44        |
# -----------------------------------------
# ======ppo Validation from:  2022-01-03 to  2022-04-04
# ppo Sharpe Ratio:  -0.0728374786469127
# ======Best Model Retraining from:  2010-01-01 to  2022-04-04
# ======Trading from:  2022-04-04 to  2022-07-06
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2022-04-04
# ======a2c Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_252_2
# ---------------------------------------
# | time/                 |             |
# |    fps                | 96          |
# |    iterations         | 100         |
# |    time_elapsed       | 5           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | -0.514      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | -80.4       |
# |    reward             | -0.48070142 |
# |    std                | 0.997       |
# |    value_loss         | 4.02        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 200        |
# |    time_elapsed       | 11         |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -0.763     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | -91        |
# |    reward             | 0.14081047 |
# |    std                | 0.998      |
# |    value_loss         | 9.59       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 300        |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0.00282    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -22.1      |
# |    reward             | -3.4851363 |
# |    std                | 0.999      |
# |    value_loss         | 3.89       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 90        |
# |    iterations         | 400       |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -26.7     |
# |    reward             | 2.0936363 |
# |    std                | 0.998     |
# |    value_loss         | 0.912     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 500       |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0.29      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | -9.23     |
# |    reward             | 0.2870687 |
# |    std                | 0.998     |
# |    value_loss         | 0.265     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 600        |
# |    time_elapsed       | 33         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -0.0503    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | -90.5      |
# |    reward             | -1.8471102 |
# |    std                | 1          |
# |    value_loss         | 11.1       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 84         |
# |    iterations         | 700        |
# |    time_elapsed       | 41         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.0241     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -109       |
# |    reward             | 0.98545575 |
# |    std                | 1          |
# |    value_loss         | 10         |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 84         |
# |    iterations         | 800        |
# |    time_elapsed       | 47         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.0951     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | -108       |
# |    reward             | 0.39941677 |
# |    std                | 1          |
# |    value_loss         | 8.48       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 86          |
# |    iterations         | 900         |
# |    time_elapsed       | 52          |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0.07        |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 899         |
# |    policy_loss        | -4.86       |
# |    reward             | -0.68538004 |
# |    std                | 1           |
# |    value_loss         | 0.587       |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 85        |
# |    iterations         | 1000      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0.11      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -32.3     |
# |    reward             | 1.4006559 |
# |    std                | 1         |
# |    value_loss         | 0.819     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 1100       |
# |    time_elapsed       | 63         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -0.00291   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1099       |
# |    policy_loss        | -466       |
# |    reward             | -1.9359884 |
# |    std                | 1          |
# |    value_loss         | 139        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 84         |
# |    iterations         | 1200       |
# |    time_elapsed       | 70         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.0242    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | -4.22      |
# |    reward             | -0.3052275 |
# |    std                | 1          |
# |    value_loss         | 11.9       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 85         |
# |    iterations         | 1300       |
# |    time_elapsed       | 75         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | 77.1       |
# |    reward             | 0.40020084 |
# |    std                | 1.01       |
# |    value_loss         | 3.85       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 1400       |
# |    time_elapsed       | 81         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0.0642     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | -99.2      |
# |    reward             | 0.56002873 |
# |    std                | 1          |
# |    value_loss         | 8.49       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 85          |
# |    iterations         | 1500        |
# |    time_elapsed       | 87          |
# |    total_timesteps    | 7500        |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1499        |
# |    policy_loss        | 55.5        |
# |    reward             | -0.18506238 |
# |    std                | 1.01        |
# |    value_loss         | 2.53        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 1600       |
# |    time_elapsed       | 92         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -0.00693   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | -37.3      |
# |    reward             | -1.0539956 |
# |    std                | 1.01       |
# |    value_loss         | 0.863      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 85         |
# |    iterations         | 1700       |
# |    time_elapsed       | 99         |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | -0.115     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1699       |
# |    policy_loss        | -57.3      |
# |    reward             | 0.55742973 |
# |    std                | 1.01       |
# |    value_loss         | 6.52       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 1800       |
# |    time_elapsed       | 104        |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | -0.219     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | 215        |
# |    reward             | -0.7836352 |
# |    std                | 1.01       |
# |    value_loss         | 35.9       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# ...
# |    fps                | 81        |
# |    iterations         | 400       |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0.125     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -86       |
# |    reward             | 0.6738413 |
# |    std                | 1         |
# |    value_loss         | 12.6      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 78         |
# |    iterations         | 500        |
# |    time_elapsed       | 31         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.039     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -23.7      |
# |    reward             | -2.5689228 |
# |    std                | 1          |
# |    value_loss         | 4.55       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 77        |
# |    iterations         | 600       |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0.000245  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 156       |
# |    reward             | 3.0892224 |
# |    std                | 1         |
# |    value_loss         | 18.5      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 73         |
# |    iterations         | 700        |
# |    time_elapsed       | 47         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.278      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -94.8      |
# |    reward             | -1.0743271 |
# |    std                | 1          |
# |    value_loss         | 8.37       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 72          |
# |    iterations         | 800         |
# |    time_elapsed       | 55          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0.161       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 799         |
# |    policy_loss        | -107        |
# |    reward             | -0.28327006 |
# |    std                | 1           |
# |    value_loss         | 7.44        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 69         |
# |    iterations         | 900        |
# |    time_elapsed       | 64         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 106        |
# |    reward             | -2.7145505 |
# |    std                | 1          |
# |    value_loss         | 7.56       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 69         |
# |    iterations         | 1000       |
# |    time_elapsed       | 71         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | -1.65      |
# |    reward             | -2.2138686 |
# |    std                | 1          |
# |    value_loss         | 0.569      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 68        |
# |    iterations         | 1100      |
# |    time_elapsed       | 80        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -0.11     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -228      |
# |    reward             | 2.5469034 |
# |    std                | 0.999     |
# |    value_loss         | 36        |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 68       |
# |    iterations         | 1200     |
# |    time_elapsed       | 87       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -41.1    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 320      |
# |    reward             | 1.493554 |
# |    std                | 0.999    |
# |    value_loss         | 90.3     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 66        |
# |    iterations         | 1300      |
# |    time_elapsed       | 97        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 617       |
# |    reward             | 3.8030493 |
# |    std                | 0.998     |
# |    value_loss         | 288       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 67       |
# |    iterations         | 1400     |
# |    time_elapsed       | 104      |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -41.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 42.9     |
# |    reward             | 0.467392 |
# |    std                | 1        |
# |    value_loss         | 1.22     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 66        |
# |    iterations         | 1500      |
# |    time_elapsed       | 113       |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -3.02     |
# |    reward             | 1.2646791 |
# |    std                | 1         |
# |    value_loss         | 0.158     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 66         |
# |    iterations         | 1600       |
# |    time_elapsed       | 120        |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -0.0202    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | -2.49      |
# |    reward             | -3.7826948 |
# |    std                | 0.999      |
# |    value_loss         | 2.16       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 65         |
# |    iterations         | 1700       |
# |    time_elapsed       | 129        |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1699       |
# |    policy_loss        | 11.2       |
# |    reward             | 0.16632019 |
# |    std                | 0.998      |
# |    value_loss         | 1.32       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 65         |
# |    iterations         | 1800       |
# |    time_elapsed       | 136        |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | -71.6      |
# |    reward             | 0.30132136 |
# |    std                | 1          |
# |    value_loss         | 4.68       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 65       |
# |    iterations         | 1900     |
# |    time_elapsed       | 144      |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -41.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -404     |
# |    reward             | 5.113882 |
# |    std                | 1        |
# |    value_loss         | 110      |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 66          |
# |    iterations         | 2000        |
# |    time_elapsed       | 149         |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1999        |
# |    policy_loss        | -603        |
# |    reward             | -0.78245443 |
# |    std                | 1           |
# |    value_loss         | 233         |
# ---------------------------------------
# ======a2c Validation from:  2023-07-07 to  2023-10-05
# a2c Sharpe Ratio:  -0.20683358821348533
# ======ddpg Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cuda device
# Logging to tensorboard_log/ddpg/ddpg_567_2
# day: 3398, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 4862620.81
# total_reward: 3862620.81
# total_cost: 1136.33
# total_trades: 40826
# Sharpe: 0.739
# =================================
# ======ddpg Validation from:  2023-07-07 to  2023-10-05
# ddpg Sharpe Ratio:  -0.2653783544058346
# ======td3 Training========
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.0001}
# Using cuda device
# Logging to tensorboard_log/td3/td3_567_2
# ======td3 Validation from:  2023-07-07 to  2023-10-05
# td3 Sharpe Ratio:  -0.21930700617764093
# ======sac Training========
# {'batch_size': 64, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cuda device
# Logging to tensorboard_log/sac/sac_567_2
# day: 3398, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 4014524.33
# total_reward: 3014524.33
# total_cost: 119748.57
# total_trades: 60406
# Sharpe: 0.677
# =================================
# ======sac Validation from:  2023-07-07 to  2023-10-05
# sac Sharpe Ratio:  -0.24444795912067882
# ======ppo Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/ppo/ppo_567_2
# -----------------------------------
# | time/              |            |
# |    fps             | 92         |
# |    iterations      | 1          |
# |    time_elapsed    | 22         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.59233856 |
# -----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 2           |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.0155548   |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.00846    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.83        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.025      |
# |    reward               | -0.17340319 |
# |    std                  | 1           |
# |    value_loss           | 17.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 3           |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012919877 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.000742   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 63.7        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0217     |
# |    reward               | 0.0746679   |
# |    std                  | 1           |
# |    value_loss           | 102         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 4           |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.018106503 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | 0.0171      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 15.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0241     |
# |    reward               | 0.47343314  |
# |    std                  | 1.01        |
# |    value_loss           | 54.3        |
# -----------------------------------------
# day: 3398, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 3423601.21
# total_reward: 2423601.21
# total_cost: 488533.00
# total_trades: 93794
# Sharpe: 0.634
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 5           |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016957896 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | -0.00826    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 27          |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0153     |
# |    reward               | 0.32269248  |
# |    std                  | 1.01        |
# |    value_loss           | 41.5        |
# -----------------------------------------
# ======ppo Validation from:  2023-07-07 to  2023-10-05
# ppo Sharpe Ratio:  -0.3404018867082875
# ======Best Model Retraining from:  2010-01-01 to  2023-10-05
# ======Trading from:  2023-10-05 to  2024-01-05
# Ensemble Strategy took:  104.350435034434  minutes

# %%
ensemble_df_summary
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe  \
# 0  126  2021-10-04  2022-01-03        TD3    0.02815   0.100504    0.122319
# 1  189  2022-01-03  2022-04-04        PPO  -0.103089  -0.072837   -0.251218
# 2  252  2022-04-04  2022-07-06        SAC  -0.271709  -0.219279    -0.20325
# 3  315  2022-07-06  2022-10-04        TD3  -0.259208   -0.20178   -0.122201
# 4  378  2022-10-04  2023-01-04        PPO   0.241052   0.252367     0.23825
# 5  441  2023-01-04  2023-04-05        TD3  -0.122321  -0.033553    0.013153
# 6  504  2023-04-05  2023-07-07       DDPG   0.139833   0.017151    0.146281
# 7  567  2023-07-07  2023-10-05        A2C  -0.206834  -0.340402   -0.265378
#
#   SAC Sharpe TD3 Sharpe
# 0     0.0744   0.188667
# 1  -0.163815  -0.152395
# 2  -0.175925  -0.267319
# 3  -0.138387  -0.074011
# 4   0.229282   0.216633
# 5  -0.044052   0.144429
# 6  -0.016065    0.11926
# 7  -0.244448  -0.219307

# %% [markdown]
# ## Part 6.2 A2C

# %%
a2c_agent = DRLSingleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window,
                 validation_window=validation_window,
                 model_name='A2C',
                 **env_kwargs)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
a2c_df_summary = a2c_agent.run_single_model_strategy(A2C_model_kwargs, 10000)
# Out:
# ============Start A2C Strategy============
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2021-10-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/A2C/A2C_126_4
# -------------------------------------
# | time/                 |           |
# |    fps                | 89        |
# |    iterations         | 100       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | -112      |
# |    reward             | 0.5159128 |
# |    std                | 1         |
# |    value_loss         | 9.1       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 94        |
# |    iterations         | 200       |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0.0613    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -23.8     |
# |    reward             | 1.8897303 |
# |    std                | 1         |
# |    value_loss         | 4.37      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 300        |
# |    time_elapsed       | 17         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.0672     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -167       |
# |    reward             | -3.9404573 |
# |    std                | 1          |
# |    value_loss         | 22.1       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 84         |
# |    iterations         | 400        |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -0.00864   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | -13.3      |
# |    reward             | 0.22080703 |
# |    std                | 1.01       |
# |    value_loss         | 4.57       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 82        |
# |    iterations         | 500       |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -0.0042   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | -38.4     |
# |    reward             | -3.422552 |
# |    std                | 1         |
# |    value_loss         | 7.94      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 85        |
# |    iterations         | 600       |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 4.38      |
# |    reward             | 1.1338098 |
# |    std                | 1         |
# |    value_loss         | 0.0831    |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 700        |
# |    time_elapsed       | 40         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -33.5      |
# |    reward             | 0.23583366 |
# |    std                | 1          |
# |    value_loss         | 0.65       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 86          |
# |    iterations         | 800         |
# |    time_elapsed       | 46          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 799         |
# |    policy_loss        | 142         |
# |    reward             | -0.33881098 |
# |    std                | 1           |
# |    value_loss         | 15.6        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 87          |
# |    iterations         | 900         |
# |    time_elapsed       | 51          |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 899         |
# |    policy_loss        | -126        |
# |    reward             | 0.026382634 |
# |    std                | 1           |
# |    value_loss         | 37.7        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 1000       |
# |    time_elapsed       | 57         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | -490       |
# |    reward             | 0.07945118 |
# |    std                | 1          |
# |    value_loss         | 234        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 1100      |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | 28.2      |
# |    reward             | 5.9820786 |
# |    std                | 1         |
# |    value_loss         | 10.7      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 1200       |
# |    time_elapsed       | 67         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | -33        |
# |    reward             | -1.4833527 |
# |    std                | 1          |
# |    value_loss         | 1.37       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 1300       |
# |    time_elapsed       | 74         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.0171    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | -2.04      |
# |    reward             | 0.29028547 |
# |    std                | 1          |
# |    value_loss         | 0.7        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 1400       |
# |    time_elapsed       | 79         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.36       |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | 176        |
# |    reward             | -1.0237721 |
# |    std                | 1          |
# |    value_loss         | 19.1       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 1500       |
# |    time_elapsed       | 85         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | 116        |
# |    reward             | 0.32554367 |
# |    std                | 1          |
# |    value_loss         | 7.86       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 88        |
# |    iterations         | 1600      |
# |    time_elapsed       | 90        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0.329     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 69        |
# |    reward             | 3.0445232 |
# |    std                | 1         |
# |    value_loss         | 9.13      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 88        |
# |    iterations         | 1700      |
# |    time_elapsed       | 95        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0.0196    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | 237       |
# |    reward             | -1.535784 |
# |    std                | 1         |
# |    value_loss         | 64.5      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 88        |
# |    iterations         | 1800      |
# |    time_elapsed       | 102       |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -81.6     |
# |    reward             | 0.6210386 |
# |    std                | 1         |
# |    value_loss         | 6.07      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 88        |
# |    iterations         | 1900      |
# |    time_elapsed       | 107       |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | 21.7      |
# |    reward             | 1.5341634 |
# |    std                | 1         |
# |    value_loss         | 2.05      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 2000       |
# |    time_elapsed       | 113        |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | 121        |
# |    reward             | 0.71510607 |
# |    std                | 1          |
# |    value_loss         | 10.7       |
# --------------------------------------
# ======A2C Validation from:  2021-10-04 to  2022-01-03
# A2C Sharpe Ratio:  -0.07661051755860736
# ======Best Model Retraining from:  2010-01-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2022-01-03
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/A2C/A2C_189_3
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 100      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -41.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -42.2    |
# |    reward             | 0.258597 |
# |    std                | 1        |
# |    value_loss         | 1.77     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 85         |
# |    iterations         | 200        |
# |    time_elapsed       | 11         |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.0459     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | -71.1      |
# |    reward             | 0.87636465 |
# |    std                | 1          |
# |    value_loss         | 6.95       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 90        |
# |    iterations         | 300       |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -0.256    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -48.4     |
# |    reward             | -2.156713 |
# |    std                | 0.998     |
# |    value_loss         | 6.56      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 90       |
# |    iterations         | 400      |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -41.1    |
# |    explained_variance | -0.00429 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -61.2    |
# |    reward             | 2.692665 |
# |    std                | 0.998    |
# |    value_loss         | 18.3     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 500        |
# |    time_elapsed       | 28         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | -0.0471    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -444       |
# |    reward             | -1.9053792 |
# |    std                | 0.996      |
# |    value_loss         | 114        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 90        |
# |    iterations         | 600       |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | -314      |
# |    reward             | 23.453773 |
# |    std                | 0.995     |
# |    value_loss         | 177       |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 87           |
# |    iterations         | 700          |
# |    time_elapsed       | 39           |
# |    total_timesteps    | 3500         |
# | train/                |              |
# |    entropy_loss       | -41          |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 699          |
# |    policy_loss        | -124         |
# |    reward             | -0.003511602 |
# |    std                | 0.995        |
# |    value_loss         | 12           |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 89        |
# |    iterations         | 800       |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | 116       |
# |    reward             | 2.1856363 |
# |    std                | 0.994     |
# |    value_loss         | 12.8      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 89        |
# |    iterations         | 900       |
# |    time_elapsed       | 50        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -58.5     |
# |    reward             | 2.4894514 |
# |    std                | 0.994     |
# |    value_loss         | 4         |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 89        |
# |    iterations         | 1000      |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 0.0135    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 166       |
# |    reward             | 1.2299596 |
# |    std                | 0.994     |
# |    value_loss         | 21.9      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 89       |
# |    iterations         | 1100     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -41      |
# |    explained_variance | 0.000305 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -118     |
# |    reward             | 5.769757 |
# |    std                | 0.993    |
# |    value_loss         | 26.4     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 88        |
# |    iterations         | 1200      |
# |    time_elapsed       | 67        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -40.9     |
# |    explained_variance | -0.00574  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -12.1     |
# |    reward             | -3.857768 |
# |    std                | 0.993     |
# |    value_loss         | 4.89      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 89        |
# |    iterations         | 1300      |
# |    time_elapsed       | 72        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -40.9     |
# |    explained_variance | 0.000802  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | -57.6     |
# |    reward             | 0.5795431 |
# |    std                | 0.992     |
# |    value_loss         | 3.18      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 89        |
# |    iterations         | 1400      |
# |    time_elapsed       | 78        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -40.9     |
# |    explained_variance | -0.0839   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 178       |
# |    reward             | 1.7586614 |
# |    std                | 0.99      |
# |    value_loss         | 27.7      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 1500       |
# |    time_elapsed       | 84         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -40.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | 155        |
# |    reward             | 0.36362946 |
# |    std                | 0.992      |
# |    value_loss         | 18.8       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 89         |
# |    iterations         | 1600       |
# |    time_elapsed       | 89         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -40.9      |
# |    explained_variance | -0.00206   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | 161        |
# |    reward             | 0.12428759 |
# |    std                | 0.991      |
# |    value_loss         | 20.4       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 88        |
# |    iterations         | 1700      |
# |    time_elapsed       | 95        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -40.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -754      |
# |    reward             | 6.4685855 |
# |    std                | 0.989     |
# |    value_loss         | 390       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 89         |
# |    iterations         | 1800       |
# |    time_elapsed       | 100        |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -40.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | 1.01e+03   |
# |    reward             | -12.968124 |
# |    std                | 0.989      |
# |    value_loss         | 1.08e+03   |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 89         |
# |    iterations         | 1900       |
# |    time_elapsed       | 106        |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -40.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1899       |
# |    policy_loss        | 2.32       |
# |    reward             | 0.26192716 |
# |    std                | 0.989      |
# |    value_loss         | 3.2        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 88          |
# |    iterations         | 2000        |
# |    time_elapsed       | 112         |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -40.8       |
# |    explained_variance | 0.00218     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1999        |
# |    policy_loss        | 187         |
# |    reward             | -0.47590038 |
# |    std                | 0.987       |
# |    value_loss         | 26.2        |
# ---------------------------------------
# ======A2C Validation from:  2022-01-03 to  2022-04-04
# A2C Sharpe Ratio:  -0.1818980079128379
# ======Best Model Retraining from:  2010-01-01 to  2022-04-04
# ======Trading from:  2022-04-04 to  2022-07-06
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2022-04-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/A2C/A2C_252_3
# --------------------------------------
# | time/                 |            |
# |    fps                | 92         |
# |    iterations         | 100        |
# |    time_elapsed       | 5          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.124     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | -52.1      |
# |    reward             | 0.20844062 |
# |    std                | 1          |
# |    value_loss         | 2.24       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 85        |
# |    iterations         | 200       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -0.0307   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -12.2     |
# |    reward             | 0.5122702 |
# |    std                | 1         |
# |    value_loss         | 2.33      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 89        |
# |    iterations         | 300       |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -46.1     |
# |    reward             | -2.223154 |
# |    std                | 1         |
# |    value_loss         | 3.45      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 400        |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | 58.7       |
# |    reward             | 0.19410436 |
# |    std                | 0.998      |
# |    value_loss         | 7.95       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 500        |
# |    time_elapsed       | 28         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 1.61e-06   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -65        |
# |    reward             | -2.1110294 |
# |    std                | 0.999      |
# |    value_loss         | 5.25       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 600       |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0.154     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | -51.7     |
# |    reward             | 4.7816286 |
# |    std                | 0.998     |
# |    value_loss         | 2         |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 700       |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0.0136    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -156      |
# |    reward             | 1.7700021 |
# |    std                | 0.998     |
# |    value_loss         | 18.1      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 88        |
# |    iterations         | 800       |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -133      |
# |    reward             | 0.5471717 |
# |    std                | 0.999     |
# |    value_loss         | 10.1      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 900        |
# |    time_elapsed       | 52         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | -2.89      |
# |    reward             | -0.7900611 |
# |    std                | 0.998      |
# |    value_loss         | 1.83       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 1000      |
# |    time_elapsed       | 57        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0.0966    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 47.1      |
# |    reward             | 2.4285104 |
# |    std                | 1         |
# |    value_loss         | 1.54      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 86       |
# |    iterations         | 1100     |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -41.1    |
# |    explained_variance | 0.00688  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 33.7     |
# |    reward             | 6.657941 |
# |    std                | 0.999    |
# |    value_loss         | 4        |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 1200       |
# |    time_elapsed       | 68         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -0.168     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | -136       |
# |    reward             | -19.750902 |
# |    std                | 1          |
# |    value_loss         | 13.7       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 1300      |
# |    time_elapsed       | 73        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -2.61     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 55        |
# |    reward             | 0.6810562 |
# |    std                | 1         |
# |    value_loss         | 2.48      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 86        |
# |    iterations         | 1400      |
# |    time_elapsed       | 80        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -0.289    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -24.7     |
# |    reward             | 0.9641561 |
# |    std                | 1         |
# |    value_loss         | 2.14      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 1500      |
# |    time_elapsed       | 85        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0.00378   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -31.4     |
# |    reward             | 0.1863267 |
# |    std                | 1         |
# |    value_loss         | 2.51      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 86          |
# |    iterations         | 1600        |
# |    time_elapsed       | 92          |
# |    total_timesteps    | 8000        |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1599        |
# |    policy_loss        | 25.4        |
# |    reward             | -0.82558185 |
# |    std                | 1           |
# |    value_loss         | 0.397       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 1700       |
# |    time_elapsed       | 97         |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -0.0102    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1699       |
# |    policy_loss        | -156       |
# |    reward             | 0.02385208 |
# |    std                | 0.999      |
# |    value_loss         | 16.1       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 87          |
# |    iterations         | 1800        |
# |    time_elapsed       | 102         |
# |    total_timesteps    | 9000        |
# | train/                |             |
# |    entropy_loss       | -41         |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1799        |
# |    policy_loss        | 337         |
# |    reward             | -0.08984203 |
# |    std                | 0.997       |
# |    value_loss         | 89.8        |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 87           |
# |    iterations         | 1900         |
# |    time_elapsed       | 108          |
# |    total_timesteps    | 9500         |
# | train/                |              |
# |    entropy_loss       | -41.1        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1899         |
# |    policy_loss        | 2.47         |
# |    reward             | -0.042344697 |
# |    std                | 0.998        |
# |    value_loss         | 0.0786       |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 2000       |
# |    time_elapsed       | 114        |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | -59.6      |
# |    reward             | -1.4418316 |
# |    std                | 1          |
# |    value_loss         | 2.42       |
# --------------------------------------
# ======A2C Validation from:  2022-04-04 to  2022-07-06
# A2C Sharpe Ratio:  -0.30421210686947975
# ======Best Model Retraining from:  2010-01-01 to  2022-07-06
# ======Trading from:  2022-07-06 to  2022-10-04
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2022-07-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/A2C/A2C_315_3
# ------------------------------------
# | time/                 |          |
# |    fps                | 74       |
# |    iterations         | 100      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -41.1    |
# |    explained_variance | -0.00419 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -24.5    |
# |    reward             | 0.570363 |
# |    std                | 0.998    |
# |    value_loss         | 0.721    |
# ------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 83           |
# |    iterations         | 200          |
# |    time_elapsed       | 12           |
# |    total_timesteps    | 1000         |
# | train/                |              |
# |    entropy_loss       | -41.1        |
# |    explained_variance | 0.0975       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 199          |
# |    policy_loss        | -51.4        |
# |    reward             | -0.054083716 |
# |    std                | 0.998        |
# |    value_loss         | 3.89         |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 79        |
# |    iterations         | 300       |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0.0774    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | 19.8      |
# |    reward             | -4.113252 |
# |    std                | 0.998     |
# |    value_loss         | 3.15      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 82        |
# |    iterations         | 400       |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | 0.7       |
# |    reward             | 0.6787422 |
# |    std                | 1         |
# |    value_loss         | 0.5       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 83         |
# |    iterations         | 500        |
# |    time_elapsed       | 30         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -67.6      |
# |    reward             | -1.0464562 |
# |    std                | 1          |
# |    value_loss         | 2.98       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 82       |
# |    iterations         | 600      |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -41.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -349     |
# |    reward             | 7.402788 |
# |    std                | 0.998    |
# |    value_loss         | 94.4     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 84         |
# |    iterations         | 700        |
# |    time_elapsed       | 41         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | 21.7       |
# |    reward             | 0.42231855 |
# |    std                | 0.998      |
# |    value_loss         | 0.755      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 82         |
# |    iterations         | 800        |
# |    time_elapsed       | 48         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 68.5       |
# |    reward             | -0.3510212 |
# |    std                | 0.998      |
# |    value_loss         | 4.5        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 83          |
# |    iterations         | 900         |
# |    time_elapsed       | 53          |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -41         |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 899         |
# |    policy_loss        | -3.36       |
# |    reward             | -0.97382855 |
# |    std                | 0.996       |
# |    value_loss         | 1.47        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 83        |
# |    iterations         | 1000      |
# |    time_elapsed       | 60        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -20.4     |
# |    reward             | 5.3909783 |
# |    std                | 0.998     |
# |    value_loss         | 0.448     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 83       |
# |    iterations         | 1100     |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -41.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 39.4     |
# |    reward             | 2.763262 |
# |    std                | 0.997    |
# |    value_loss         | 2.13     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 84         |
# |    iterations         | 1200       |
# |    time_elapsed       | 70         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | -265       |
# |    reward             | -0.7244893 |
# |    std                | 0.996      |
# |    value_loss         | 46         |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 83           |
# |    iterations         | 1300         |
# |    time_elapsed       | 77           |
# |    total_timesteps    | 6500         |
# | train/                |              |
# |    entropy_loss       | -41          |
# |    explained_variance | 4.17e-07     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1299         |
# |    policy_loss        | 2.27         |
# |    reward             | -0.057615466 |
# |    std                | 0.994        |
# |    value_loss         | 0.249        |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 84        |
# |    iterations         | 1400      |
# |    time_elapsed       | 82        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -40.9     |
# |    explained_variance | 0.0351    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -67.5     |
# |    reward             | -1.791878 |
# |    std                | 0.993     |
# |    value_loss         | 3.63      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 83        |
# |    iterations         | 1500      |
# |    time_elapsed       | 89        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -40.9     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -187      |
# |    reward             | 3.7146041 |
# ...
# |    time_elapsed       | 95        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -0.192    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 120       |
# |    reward             | 1.3413427 |
# |    std                | 1.01      |
# |    value_loss         | 11.8      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 82         |
# |    iterations         | 1700       |
# |    time_elapsed       | 102        |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1699       |
# |    policy_loss        | 19.5       |
# |    reward             | -1.5917367 |
# |    std                | 1.01       |
# |    value_loss         | 2.96       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 83         |
# |    iterations         | 1800       |
# |    time_elapsed       | 108        |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -0.142     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | -159       |
# |    reward             | -3.2932875 |
# |    std                | 1.01       |
# |    value_loss         | 54.1       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 82        |
# |    iterations         | 1900      |
# |    time_elapsed       | 114       |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0.0459    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | -269      |
# |    reward             | -5.437467 |
# |    std                | 1         |
# |    value_loss         | 95.1      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 83       |
# |    iterations         | 2000     |
# |    time_elapsed       | 120      |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -41.3    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 163      |
# |    reward             | 2.056168 |
# |    std                | 1.01     |
# |    value_loss         | 76.6     |
# ------------------------------------
# ======A2C Validation from:  2023-04-05 to  2023-07-07
# A2C Sharpe Ratio:  0.032844429049728355
# ======Best Model Retraining from:  2010-01-01 to  2023-07-07
# ======Trading from:  2023-07-07 to  2023-10-05
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2023-07-07
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/A2C/A2C_567_2
# ---------------------------------------
# | time/                 |             |
# |    fps                | 71          |
# |    iterations         | 100         |
# |    time_elapsed       | 7           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | -0.0802     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | -70.8       |
# |    reward             | 0.076121904 |
# |    std                | 0.999       |
# |    value_loss         | 3.71        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 80        |
# |    iterations         | 200       |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -0.314    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | 18.9      |
# |    reward             | 1.4652953 |
# |    std                | 0.999     |
# |    value_loss         | 2.12      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 79        |
# |    iterations         | 300       |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0.246     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -96.1     |
# |    reward             | -4.497835 |
# |    std                | 0.999     |
# |    value_loss         | 9.45      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 80         |
# |    iterations         | 400        |
# |    time_elapsed       | 24         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | 45.3       |
# |    reward             | 0.33245057 |
# |    std                | 1          |
# |    value_loss         | 13.3       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 82         |
# |    iterations         | 500        |
# |    time_elapsed       | 30         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0.0411     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -85.7      |
# |    reward             | -1.1011374 |
# |    std                | 1          |
# |    value_loss         | 6.37       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 80       |
# |    iterations         | 600      |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -41.2    |
# |    explained_variance | 0.17     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 163      |
# |    reward             | 4.733832 |
# |    std                | 1        |
# |    value_loss         | 22.3     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 82          |
# |    iterations         | 700         |
# |    time_elapsed       | 42          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0.106       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 699         |
# |    policy_loss        | -74         |
# |    reward             | -0.95440495 |
# |    std                | 1           |
# |    value_loss         | 6.74        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 80         |
# |    iterations         | 800        |
# |    time_elapsed       | 49         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.287     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | -65.2      |
# |    reward             | -0.2563851 |
# |    std                | 1          |
# |    value_loss         | 3.19       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 81         |
# |    iterations         | 900        |
# |    time_elapsed       | 55         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 95.4       |
# |    reward             | -2.8253639 |
# |    std                | 0.999      |
# |    value_loss         | 6.81       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 80         |
# |    iterations         | 1000       |
# |    time_elapsed       | 62         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0.0132     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | -25        |
# |    reward             | -2.2847178 |
# |    std                | 0.998      |
# |    value_loss         | 2.1        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 81        |
# |    iterations         | 1100      |
# |    time_elapsed       | 67        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0.0677    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -45.6     |
# |    reward             | 2.6499422 |
# |    std                | 0.999     |
# |    value_loss         | 6.85      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 81        |
# |    iterations         | 1200      |
# |    time_elapsed       | 73        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0.0675    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -74.1     |
# |    reward             | 4.9785104 |
# |    std                | 0.999     |
# |    value_loss         | 44.3      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 80        |
# |    iterations         | 1300      |
# |    time_elapsed       | 80        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -0.0474   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | -484      |
# |    reward             | 19.011444 |
# |    std                | 1         |
# |    value_loss         | 194       |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 81          |
# |    iterations         | 1400        |
# |    time_elapsed       | 85          |
# |    total_timesteps    | 7000        |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | 0.598       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1399        |
# |    policy_loss        | -23.7       |
# |    reward             | 0.018479975 |
# |    std                | 1           |
# |    value_loss         | 0.474       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 80         |
# |    iterations         | 1500       |
# |    time_elapsed       | 92         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | -18.9      |
# |    reward             | 0.40878242 |
# |    std                | 1          |
# |    value_loss         | 0.337      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 81        |
# |    iterations         | 1600      |
# |    time_elapsed       | 98        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0.0478    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 5.3       |
# |    reward             | -2.482395 |
# |    std                | 1         |
# |    value_loss         | 1.46      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 80        |
# |    iterations         | 1700      |
# |    time_elapsed       | 105       |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0.0423    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -43.2     |
# |    reward             | 4.8756504 |
# |    std                | 1         |
# |    value_loss         | 10.5      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 81         |
# |    iterations         | 1800       |
# |    time_elapsed       | 110        |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0.0256     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | 140        |
# |    reward             | -3.4466262 |
# |    std                | 1          |
# |    value_loss         | 18.1       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 81       |
# |    iterations         | 1900     |
# |    time_elapsed       | 116      |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -41.3    |
# |    explained_variance | 0.107    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -287     |
# |    reward             | 6.307991 |
# |    std                | 1        |
# |    value_loss         | 64.3     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 81        |
# |    iterations         | 2000      |
# |    time_elapsed       | 123       |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | -468      |
# |    reward             | 1.0479817 |
# |    std                | 1         |
# |    value_loss         | 165       |
# -------------------------------------
# ======A2C Validation from:  2023-07-07 to  2023-10-05
# A2C Sharpe Ratio:  -0.21311243444558112
# ======Best Model Retraining from:  2010-01-01 to  2023-10-05
# ======Trading from:  2023-10-05 to  2024-01-05
# Strategy took:  16.10518777767817  minutes

# %%
a2c_df_summary
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   Iter   Val Start     Val End A2C Sharpe
# 0  126  2021-10-04  2022-01-03  -0.076611
# 1  189  2022-01-03  2022-04-04  -0.181898
# 2  252  2022-04-04  2022-07-06  -0.304212
# 3  315  2022-07-06  2022-10-04  -0.114943
# 4  378  2022-10-04  2023-01-04   0.206118
# 5  441  2023-01-04  2023-04-05  -0.055602
# 6  504  2023-04-05  2023-07-07   0.032844
# 7  567  2023-07-07  2023-10-05  -0.213112

# %% [markdown]
# ## Part 6.3 PPO Only

# %%
ppo_agent = DRLSingleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window,
                 validation_window=validation_window,
                 model_name='PPO',
                 **env_kwargs)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
ppo_df_summary = ppo_agent.run_single_model_strategy(PPO_model_kwargs, 10000)
ppo_df_summary
# Out:
# ============Start PPO Strategy============
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2021-10-04
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/PPO/PPO_126_3
# ----------------------------------
# | time/              |           |
# |    fps             | 93        |
# |    iterations      | 1         |
# |    time_elapsed    | 21        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 0.6854551 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 2           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013091562 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.00031     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.48        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0299     |
# |    reward               | 0.8466451   |
# |    std                  | 1           |
# |    value_loss           | 8.83        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 3           |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016041478 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 1.54e-05    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 14.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.022      |
# |    reward               | 0.038391106 |
# |    std                  | 1           |
# |    value_loss           | 30.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 4           |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015830424 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0163     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 19.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0199     |
# |    reward               | 3.5378435   |
# |    std                  | 1.01        |
# |    value_loss           | 39.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 5           |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.02651586  |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | 0.0115      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.93        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0283     |
# |    reward               | -0.33072555 |
# |    std                  | 1.01        |
# |    value_loss           | 16.4        |
# -----------------------------------------
# ======PPO Validation from:  2021-10-04 to  2022-01-03
# PPO Sharpe Ratio:  0.05826228615678417
# ======Best Model Retraining from:  2010-01-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2022-01-03
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/PPO/PPO_189_2
# ----------------------------------
# | time/              |           |
# |    fps             | 96        |
# |    iterations      | 1         |
# |    time_elapsed    | 21        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 1.9193004 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 2           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.022155493 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.0281      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.49        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0297     |
# |    reward               | -1.7873368  |
# |    std                  | 1           |
# |    value_loss           | 13.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 3           |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.017858155 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.00926    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 33.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0182     |
# |    reward               | -0.81363803 |
# |    std                  | 1           |
# |    value_loss           | 69.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 4           |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.016804617 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | 0.00041     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 29.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0175     |
# |    reward               | -4.1905174  |
# |    std                  | 1           |
# |    value_loss           | 59.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 5           |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.015292389 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.00404    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.44        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0222     |
# |    reward               | -0.4637508  |
# |    std                  | 1           |
# |    value_loss           | 17.3        |
# -----------------------------------------
# ======PPO Validation from:  2022-01-03 to  2022-04-04
# PPO Sharpe Ratio:  -0.15521238157017234
# ======Best Model Retraining from:  2010-01-01 to  2022-04-04
# ======Trading from:  2022-04-04 to  2022-07-06
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2022-04-04
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/PPO/PPO_252_2
# ---------------------------------
# | time/              |          |
# |    fps             | 94       |
# |    iterations      | 1        |
# |    time_elapsed    | 21       |
# |    total_timesteps | 2048     |
# | train/             |          |
# |    reward          | 1.572215 |
# ---------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 2           |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013821369 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | -0.0185     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.71        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.023      |
# |    reward               | -0.41553593 |
# |    std                  | 1           |
# |    value_loss           | 13.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 92         |
# |    iterations           | 3          |
# |    time_elapsed         | 66         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01424238 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | -0.00133   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 43.5       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.021     |
# |    reward               | -5.619819  |
# |    std                  | 1          |
# |    value_loss           | 86.3       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 4           |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.018153291 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.0129      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 20.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0174     |
# |    reward               | 0.2190874   |
# |    std                  | 1           |
# |    value_loss           | 46.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 5           |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.018096752 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.0376     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.12        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0196     |
# |    reward               | -0.48426822 |
# |    std                  | 1           |
# |    value_loss           | 10.8        |
# -----------------------------------------
# ======PPO Validation from:  2022-04-04 to  2022-07-06
# PPO Sharpe Ratio:  -0.25134615048707254
# ======Best Model Retraining from:  2010-01-01 to  2022-07-06
# ======Trading from:  2022-07-06 to  2022-10-04
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2022-07-06
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/PPO/PPO_315_2
# ----------------------------------
# | time/              |           |
# |    fps             | 89        |
# |    iterations      | 1         |
# |    time_elapsed    | 22        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 1.0009779 |
# ----------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 91         |
# |    iterations           | 2          |
# |    time_elapsed         | 44         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01465181 |
# |    clip_fraction        | 0.19       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | 0.01       |
# |    learning_rate        | 0.00025    |
# |    loss                 | 5.63       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0251    |
# |    reward               | 5.042473   |
# |    std                  | 1          |
# |    value_loss           | 11.5       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 3           |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013304983 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.00424    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 27.3        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0184     |
# |    reward               | 4.5565248   |
# |    std                  | 1           |
# |    value_loss           | 76          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 4           |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.014506092 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | 0.00986     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 65.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0197     |
# |    reward               | 1.0531918   |
# |    std                  | 1           |
# |    value_loss           | 94.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 5           |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.022654843 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | 0.015       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 12.1        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0253     |
# |    reward               | 0.64119595  |
# |    std                  | 1.01        |
# |    value_loss           | 23.1        |
# -----------------------------------------
# ======PPO Validation from:  2022-07-06 to  2022-10-04
# PPO Sharpe Ratio:  -0.17511139789413244
# ======Best Model Retraining from:  2010-01-01 to  2022-10-04
# ======Trading from:  2022-10-04 to  2023-01-04
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2022-10-04
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/PPO/PPO_378_2
# ------------------------------------
# | time/              |             |
# |    fps             | 89          |
# |    iterations      | 1           |
# |    time_elapsed    | 22          |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | -0.11114766 |
# ------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 2           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016983347 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.00317    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.78        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0303     |
# |    reward               | -0.1963708  |
# |    std                  | 1           |
# |    value_loss           | 10.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 3           |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012763522 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.00457    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 19.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0218     |
# |    reward               | -1.4476907  |
# |    std                  | 1           |
# |    value_loss           | 49.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 4           |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.016894951 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0368     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.76        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0214     |
# |    reward               | 0.018198704 |
# |    std                  | 1.01        |
# |    value_loss           | 30          |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 90         |
# |    iterations           | 5          |
# |    time_elapsed         | 113        |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01652981 |
# |    clip_fraction        | 0.161      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.4      |
# |    explained_variance   | -0.00373   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 6.1        |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0226    |
# |    reward               | 0.65274054 |
# |    std                  | 1.01       |
# |    value_loss           | 18.2       |
# ----------------------------------------
# ======PPO Validation from:  2022-10-04 to  2023-01-04
# PPO Sharpe Ratio:  0.06456736510161643
# ======Best Model Retraining from:  2010-01-01 to  2023-01-04
# ======Trading from:  2023-01-04 to  2023-04-05
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2023-01-04
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/PPO/PPO_441_2
# ----------------------------------
# | time/              |           |
# |    fps             | 94        |
# |    iterations      | 1         |
# |    time_elapsed    | 21        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 1.4135045 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 2           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.017581265 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.023      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.37        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.031      |
# |    reward               | 0.271692    |
# |    std                  | 1           |
# |    value_loss           | 10.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 3           |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012975781 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.00677    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 39.7        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.019      |
# |    reward               | -1.2336111  |
# |    std                  | 1           |
# |    value_loss           | 79.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 4           |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015678797 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.00323    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.79        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0247     |
# |    reward               | 0.24068019  |
# |    std                  | 1           |
# |    value_loss           | 27.8        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 88         |
# |    iterations           | 5          |
# |    time_elapsed         | 115        |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01811713 |
# |    clip_fraction        | 0.219      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.3      |
# |    explained_variance   | -0.014     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 10.6       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0214    |
# |    reward               | -2.673952  |
# |    std                  | 1.01       |
# |    value_loss           | 22.5       |
# ----------------------------------------
# ======PPO Validation from:  2023-01-04 to  2023-04-05
# PPO Sharpe Ratio:  -0.1250358398814991
# ======Best Model Retraining from:  2010-01-01 to  2023-04-05
# ======Trading from:  2023-04-05 to  2023-07-07
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2023-04-05
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/PPO/PPO_504_2
# -----------------------------------
# | time/              |            |
# |    fps             | 86         |
# |    iterations      | 1          |
# |    time_elapsed    | 23         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.53124243 |
# -----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 2           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.018994283 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.0108      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.35        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0321     |
# |    reward               | 0.65687656  |
# |    std                  | 1           |
# |    value_loss           | 10.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 3           |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.018484265 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -6.69e-05   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 35.8        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.022      |
# |    reward               | -1.3396003  |
# |    std                  | 1.01        |
# |    value_loss           | 50.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 4           |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015481588 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.00567    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 23.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0219     |
# |    reward               | 1.8366364   |
# |    std                  | 1.01        |
# |    value_loss           | 60.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 5           |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.018560987 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | -0.0181     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 17.7        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.025      |
# |    reward               | 0.41184717  |
# |    std                  | 1.01        |
# |    value_loss           | 45.3        |
# -----------------------------------------
# ======PPO Validation from:  2023-04-05 to  2023-07-07
# PPO Sharpe Ratio:  0.017525927858720192
# ======Best Model Retraining from:  2010-01-01 to  2023-07-07
# ======Trading from:  2023-07-07 to  2023-10-05
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2023-07-07
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/PPO/PPO_567_2
# ----------------------------------
# | time/              |           |
# |    fps             | 92        |
# |    iterations      | 1         |
# |    time_elapsed    | 22        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 1.1189914 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 2           |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.01611602  |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.0214     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.19        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0246     |
# |    reward               | -0.37499863 |
# |    std                  | 1           |
# |    value_loss           | 10.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 3           |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011694951 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.00672    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 29.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0179     |
# |    reward               | 1.2515119   |
# |    std                  | 1           |
# |    value_loss           | 67.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 4           |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013584858 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.00332    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 14.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.017      |
# |    reward               | 0.15107006  |
# |    std                  | 1           |
# |    value_loss           | 39.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 86           |
# |    iterations           | 5            |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.01793909   |
# |    clip_fraction        | 0.197        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.2        |
# |    explained_variance   | -0.000408    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 15           |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0224      |
# |    reward               | -0.013985902 |
# |    std                  | 1            |
# |    value_loss           | 35.2         |
# ------------------------------------------
# ======PPO Validation from:  2023-07-07 to  2023-10-05
# PPO Sharpe Ratio:  -0.1493185519748575
# ======Best Model Retraining from:  2010-01-01 to  2023-10-05
# ======Trading from:  2023-10-05 to  2024-01-05
# Strategy took:  15.600331695874532  minutes
#   Iter   Val Start     Val End PPO Sharpe
# 0  126  2021-10-04  2022-01-03   0.058262
# 1  189  2022-01-03  2022-04-04  -0.155212
# 2  252  2022-04-04  2022-07-06  -0.251346
# 3  315  2022-07-06  2022-10-04  -0.175111
# 4  378  2022-10-04  2023-01-04   0.064567
# 5  441  2023-01-04  2023-04-05  -0.125036
# 6  504  2023-04-05  2023-07-07   0.017526
# 7  567  2023-07-07  2023-10-05  -0.149319

# %% [markdown]
# ## Part 6.4 DDPG Only

# %%
ddpg_agent = DRLSingleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window,
                 validation_window=validation_window,
                 model_name='DDPG',
                 **env_kwargs)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
ddpg_df_summary = ddpg_agent.run_single_model_strategy(DDPG_model_kwargs, 10000)
ddpg_df_summary
# Out:
# ============Start DDPG Strategy============
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2021-10-04
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cuda device
# Logging to tensorboard_log/DDPG/DDPG_126_2
# ======DDPG Validation from:  2021-10-04 to  2022-01-03
# DDPG Sharpe Ratio:  -0.007332083861417479
# ======Best Model Retraining from:  2010-01-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2022-01-03
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cuda device
# Logging to tensorboard_log/DDPG/DDPG_189_2
# ======DDPG Validation from:  2022-01-03 to  2022-04-04
# DDPG Sharpe Ratio:  -0.25354031635046126
# ======Best Model Retraining from:  2010-01-01 to  2022-04-04
# ======Trading from:  2022-04-04 to  2022-07-06
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2022-04-04
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cuda device
# Logging to tensorboard_log/DDPG/DDPG_252_2
# ======DDPG Validation from:  2022-04-04 to  2022-07-06
# DDPG Sharpe Ratio:  -0.190630890400674
# ======Best Model Retraining from:  2010-01-01 to  2022-07-06
# ======Trading from:  2022-07-06 to  2022-10-04
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2022-07-06
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cuda device
# Logging to tensorboard_log/DDPG/DDPG_315_2
# ======DDPG Validation from:  2022-07-06 to  2022-10-04
# DDPG Sharpe Ratio:  -0.0738334870557332
# ======Best Model Retraining from:  2010-01-01 to  2022-10-04
# ======Trading from:  2022-10-04 to  2023-01-04
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2022-10-04
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cuda device
# Logging to tensorboard_log/DDPG/DDPG_378_2
# ======DDPG Validation from:  2022-10-04 to  2023-01-04
# DDPG Sharpe Ratio:  0.13193289982018877
# ======Best Model Retraining from:  2010-01-01 to  2023-01-04
# ======Trading from:  2023-01-04 to  2023-04-05
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2023-01-04
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cuda device
# Logging to tensorboard_log/DDPG/DDPG_441_2
# ======DDPG Validation from:  2023-01-04 to  2023-04-05
# DDPG Sharpe Ratio:  0.1325907957435083
# ======Best Model Retraining from:  2010-01-01 to  2023-04-05
# ======Trading from:  2023-04-05 to  2023-07-07
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2023-04-05
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cuda device
# Logging to tensorboard_log/DDPG/DDPG_504_2
# ======DDPG Validation from:  2023-04-05 to  2023-07-07
# DDPG Sharpe Ratio:  0.043208738012707776
# ======Best Model Retraining from:  2010-01-01 to  2023-07-07
# ======Trading from:  2023-07-07 to  2023-10-05
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2023-07-07
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cuda device
# Logging to tensorboard_log/DDPG/DDPG_567_2
# ======DDPG Validation from:  2023-07-07 to  2023-10-05
# DDPG Sharpe Ratio:  0.08726171915605678
# ======Best Model Retraining from:  2010-01-01 to  2023-10-05
# ======Trading from:  2023-10-05 to  2024-01-05
# Strategy took:  21.936719437440235  minutes
#   Iter   Val Start     Val End DDPG Sharpe
# 0  126  2021-10-04  2022-01-03   -0.007332
# 1  189  2022-01-03  2022-04-04    -0.25354
# 2  252  2022-04-04  2022-07-06   -0.190631
# 3  315  2022-07-06  2022-10-04   -0.073833
# 4  378  2022-10-04  2023-01-04    0.131933
# 5  441  2023-01-04  2023-04-05    0.132591
# 6  504  2023-04-05  2023-07-07    0.043209
# 7  567  2023-07-07  2023-10-05    0.087262

# %% [markdown]
# ## Part 6.5 MBRL Random Shooting

# %%
mbrl_agent = MBRLAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window,
                 validation_window=validation_window,

                 **env_kwargs)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
mbrl_df_summary = mbrl_agent.run_MBRL_strategy(10000)
mbrl_df_summary
# Out:
# ============Start MBRL Strategy============
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2021-10-04
# ======MBRL Training========
# ======MBRL Validation from:  2021-10-04 to  2022-01-03
# MBRL Sharpe Ratio:  0.20692708110463173
# ======Trading from:  2022-01-03 to  2022-04-04
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2022-01-03
# ======MBRL Training========
# ======MBRL Validation from:  2022-01-03 to  2022-04-04
# MBRL Sharpe Ratio:  -0.37534008824881665
# ======Trading from:  2022-04-04 to  2022-07-06
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2022-04-04
# ======MBRL Training========
# ======MBRL Validation from:  2022-04-04 to  2022-07-06
# MBRL Sharpe Ratio:  -0.25618610238543676
# ======Trading from:  2022-07-06 to  2022-10-04
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2022-07-06
# ======MBRL Training========
# ======MBRL Validation from:  2022-07-06 to  2022-10-04
# MBRL Sharpe Ratio:  -0.11267374173373253
# ======Trading from:  2022-10-04 to  2023-01-04
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2022-10-04
# ======MBRL Training========
# ======MBRL Validation from:  2022-10-04 to  2023-01-04
# MBRL Sharpe Ratio:  0.25101181851830506
# ======Trading from:  2023-01-04 to  2023-04-05
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2023-01-04
# ======MBRL Training========
# ======MBRL Validation from:  2023-01-04 to  2023-04-05
# MBRL Sharpe Ratio:  -0.07587035028917608
# ======Trading from:  2023-04-05 to  2023-07-07
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2023-04-05
# ======MBRL Training========
# ======MBRL Validation from:  2023-04-05 to  2023-07-07
# MBRL Sharpe Ratio:  -0.11085007191448906
# ======Trading from:  2023-07-07 to  2023-10-05
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2023-07-07
# ======MBRL Training========
# ======MBRL Validation from:  2023-07-07 to  2023-10-05
# MBRL Sharpe Ratio:  -0.28425999523762097
# ======Trading from:  2023-10-05 to  2024-01-05
# Strategy took:  25.784725014368693  minutes
#   Iter   Val Start     Val End MBRL Sharpe
# 0  126  2021-10-04  2022-01-03    0.206927
# 1  189  2022-01-03  2022-04-04    -0.37534
# 2  252  2022-04-04  2022-07-06   -0.256186
# 3  315  2022-07-06  2022-10-04   -0.112674
# 4  378  2022-10-04  2023-01-04    0.251012
# 5  441  2023-01-04  2023-04-05    -0.07587
# 6  504  2023-04-05  2023-07-07    -0.11085
# 7  567  2023-07-07  2023-10-05    -0.28426

# %% [markdown]
# ## Part 6.6 PETS

# %%
from finrl.agents.stablebaselines3 import pets_model
from finrl.meta.env_stock_trading import env_stocktrading
importlib.reload(pets_model)
importlib.reload(env_stocktrading)
from finrl.agents.stablebaselines3.pets_model import PETSAgent
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
pets_agent = PETSAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window,
                 validation_window=validation_window,
                 **env_kwargs)

# %%
pets_df_summary = pets_agent.run_strategy(10000)
pets_df_summary
# Out:
# ============Start PETS Strategy============
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2021-10-04
# ======PETS Training (PETS)========
# hiiiiiii
# ======PETS Validation from:  2021-10-04 to  2022-01-03
# PETS Sharpe Ratio:  0.029527535289378237
# ======Trading from:  2022-01-03 to  2022-04-04
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2022-01-03
# ======PETS Training (PETS)========
# hiiiiiii
# ======PETS Validation from:  2022-01-03 to  2022-04-04
# PETS Sharpe Ratio:  -0.10076798822379673
# ======Trading from:  2022-04-04 to  2022-07-06
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2022-04-04
# ======PETS Training (PETS)========
# hiiiiiii
# ======PETS Validation from:  2022-04-04 to  2022-07-06
# PETS Sharpe Ratio:  -0.1430893029435555
# ======Trading from:  2022-07-06 to  2022-10-04
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2022-07-06
# ======PETS Training (PETS)========
# hiiiiiii
# ======PETS Validation from:  2022-07-06 to  2022-10-04
# PETS Sharpe Ratio:  -0.14755960958736208
# ======Trading from:  2022-10-04 to  2023-01-04
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2022-10-04
# ======PETS Training (PETS)========
# hiiiiiii
# ======PETS Validation from:  2022-10-04 to  2023-01-04
# PETS Sharpe Ratio:  0.07907611474338373
# ======Trading from:  2023-01-04 to  2023-04-05
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2023-01-04
# ======PETS Training (PETS)========
# hiiiiiii
# ======PETS Validation from:  2023-01-04 to  2023-04-05
# PETS Sharpe Ratio:  -0.08342384857749313
# ======Trading from:  2023-04-05 to  2023-07-07
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2023-04-05
# ======PETS Training (PETS)========
# hiiiiiii
# ======PETS Validation from:  2023-04-05 to  2023-07-07
# PETS Sharpe Ratio:  -0.1268608824336452
# ======Trading from:  2023-07-07 to  2023-10-05
# ============================================
# turbulence_threshold:  201.71827042919944
# ======Model training from:  2010-01-01 to  2023-07-07
# ======PETS Training (PETS)========
# hiiiiiii
# ======PETS Validation from:  2023-07-07 to  2023-10-05
# PETS Sharpe Ratio:  -0.5572879612610587
# ======Trading from:  2023-10-05 to  2024-01-05
# Strategy took:  64.59786781072617  minutes
#   Iter   Val Start     Val End PETS Sharpe
# 0  126  2021-10-04  2022-01-03    0.029528
# 1  189  2022-01-03  2022-04-04   -0.100768
# 2  252  2022-04-04  2022-07-06   -0.143089
# 3  315  2022-07-06  2022-10-04    -0.14756
# 4  378  2022-10-04  2023-01-04    0.079076
# 5  441  2023-01-04  2023-04-05   -0.083424
# 6  504  2023-04-05  2023-07-07   -0.126861
# 7  567  2023-07-07  2023-10-05   -0.557288

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
models = ['A2C', 'PPO', 'DDPG', 'ensemble', 'MBRL', 'PETS']
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for model in models:
    for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
        temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format(model,i))
        temp['model'] = model
        df_account_value = pd.concat([df_account_value, temp], ignore_index=True)
    sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()

a2c_account_value = df_account_value[df_account_value['model']=='A2C'].join(df_trade_date[validation_window:].reset_index(drop=True))
ppo_account_value = df_account_value[df_account_value['model']=='PPO'].join(df_trade_date[validation_window:].reset_index(drop=True))
ddpg_account_value = df_account_value[df_account_value['model']=='DDPG'].join(df_trade_date[validation_window:].reset_index(drop=True))
ensemble_account_value = df_account_value[df_account_value['model']=='ensemble'].join(df_trade_date[validation_window:].reset_index(drop=True))
mbrl_account_value = df_account_value[df_account_value['model']=='MBRL'].join(df_trade_date[validation_window:].reset_index(drop=True))
pets_account_value = df_account_value[df_account_value['model']=='PETS'].join(df_trade_date[validation_window:].reset_index(drop=True))

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
#baseline stats
print("==============Get Baseline Stats===========")
df_dji_ = get_baseline(
        ticker="^DJI",
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(df_dji_, value_col_name = 'close')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [*********************100%***********************]  1 of 1 completed
# ==============Get Baseline Stats===========
# Shape of DataFrame:  (503, 8)
# Annual return          0.017877
# Cumulative returns     0.036002
# Annual volatility      0.150962
# Sharpe ratio           0.192962
# Calmar ratio           0.082406
# Stability              0.100862
# Max drawdown          -0.216945
# Omega ratio            1.033061
# Sortino ratio          0.272084
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.920127
# Daily value at risk   -0.018904
# dtype: float64

# %%
df_dji = pd.DataFrame()
df_dji['date'] = a2c_account_value['date']
df_dji['dji'] = df_dji_['close'] / df_dji_['close'][0] * env_kwargs["initial_amount"]

df_dji.to_csv("df_dji.csv")
df_dji = df_dji.set_index(df_dji.columns[0])

df_dji.to_csv("df_dji+.csv")

df_account_value.to_csv('df_account_value.csv')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
# %matplotlib inline
df.to_csv("df.csv")
df_result_a2c = pd.DataFrame({'date': a2c_account_value['date'], 'A2C': a2c_account_value['account_value']})
df_result_a2c = df_result_a2c.set_index('date')
df_result_a2c.to_csv("df_result_a2c.csv")

df_result_ppo = pd.DataFrame({'date': ppo_account_value['date'], 'PPO': ppo_account_value['account_value']})
df_result_ppo = df_result_ppo.set_index('date')
df_result_ppo.to_csv("df_result_ppo.csv")

df_result_ddpg = pd.DataFrame({'date': ddpg_account_value['date'], 'DDPG': ddpg_account_value['account_value']})
df_result_ddpg = df_result_ddpg.set_index('date')
df_result_ddpg.to_csv("df_result_ddpg.csv")

df_result_ensemble = pd.DataFrame({'date': a2c_account_value['date'], 'ensemble': df_account_value['account_value']})
df_result_ensemble = df_result_ensemble[:504].set_index('date')
df_result_ensemble.to_csv("df_result_ensemble.csv")

df_result_mbrl = pd.DataFrame({'date': mbrl_account_value['date'], 'MBRL': mbrl_account_value['account_value']})
df_result_mbrl = df_result_mbrl.set_index('date')
df_result_mbrl.to_csv("df_result_mbrl.csv")

df_result_pets = pd.DataFrame({'date': pets_account_value['date'], 'PETS': pets_account_value['account_value']})
df_result_pets = df_result_pets.set_index('date')
df_result_pets.to_csv("df_result_pets.csv")

result = pd.DataFrame()
result = pd.concat([df_result_a2c, df_result_ppo, df_result_ddpg, df_result_ensemble, df_result_mbrl, df_result_pets, df_dji],axis=1)
result.to_csv("result.csv")
result.columns = ['A2C', 'PPO', 'DDPG', 'Ensemble', 'MBRL', 'PETS', 'dji']

# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure();
result.plot();
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_result_ensemble
